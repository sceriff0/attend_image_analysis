# %%
import pandas as pd
import numpy as np
from scipy.spatial import Delaunay
from collections import Counter
import os
from datetime import datetime
import re

# %%
def count_interactions(data, triangulation_data, colname):
    tri = triangulation_data
    labels = list(data[colname])
    labels_df = pd.DataFrame({'label': labels})
    pairs = []
    for simplex in tri.simplices:
        # Get the labels of the triangle’s three points
        simplex_labels = labels_df.loc[simplex, 'label'].values
        
        for i in range(3):
            for j in range(i + 1, 3):
                pair = tuple(sorted([simplex_labels[i], simplex_labels[j]]))
                pairs.append(pair)
    
    # Count unordered pairs
    pair_counts = Counter(pair for pair in pairs)
    # pair_counts = Counter(pair for pair in pairs_test)
    
    # Build list of rows for DataFrame
    counts_data = [("{}".format('-'.join(sorted(pair))), count) for pair, count in pair_counts.items()]
    
    # Create DataFrame
    interactions_count_df = pd.DataFrame(counts_data, columns=['interaction', 'interaction_count'])
    
    return interactions_count_df


def count_interactions_delaunay(data, colname):
    points = data[['x', 'y']].to_numpy()
    tri = Delaunay(points)
    interactions_count_df = count_interactions(data, tri, colname)

    return interactions_count_df

# %%
def create_interactions_count_df(files_list, outdir='data', write=True):

    interactions_list = []
    
    for file in files_list:
        match = re.search(r'/([^/]+)_analysis/', file)
        patient_id = match.group(1) if match else None
    
        print(f"Loading {file}")
        data = pd.read_csv(file, index_col=0)
    
        print("Counting interactions...")
        interactions_count_df = count_interactions_delaunay(data, "phenotype")
        interactions_count_df["patient_id"] = patient_id
    
        print(interactions_count_df.head())
    
        # Get current datetime
        now = datetime.now()
        
        os.makedirs('tmp', exist_ok=True)
    
        output_file = os.path.join('tmp', f"{patient_id}_interactions_{now.strftime('%Y%m%d%H%M')}.csv")
    
        print(f"Saving to {output_file}")
        interactions_count_df.to_csv(output_file)
    
        print("Adding to list...")
        interactions_list.append(interactions_count_df)

    interactions_df = pd.concat(interactions_list, ignore_index=True)

    if write:
        interactions_df.to_csv(os.path.join(outdir, f"cell_type_interactions_{now.strftime('%Y%m%d%H%M')}.csv"), index=False)

    return interactions_df

# %%
filename = 'phenotypes.csv'
filename = 'phenotypes_20250723.csv'
root_dir = '/hpcnfs/techunits/imaging/work/ATTEND/analysis_runs'

patient_ids_list = [
    '23S64',
    '35138',
    '19E110099A4',
    '1826315',
    'B19-10215',
    '21S188',
    '21-37601',
    '1923575',
    '23S22',
    '1818600'
    ]



files_list = [os.path.join(root_dir, f"{patient_id}_analysis", "output", filename) for patient_id in patient_ids_list]

# %%
interactions_df = create_interactions_count_df(files_list, outdir='data', write=True)
# Out:
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/23S64_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0      Stroma SMA-Stroma SMA             544506  phenotypes
# 1    Stroma SMA-Unclassified             431332  phenotypes
# 2  Unclassified-Unclassified             776817  phenotypes
# 3                Tumor-Tumor             461062  phenotypes
# 4         Tumor-Unclassified              51786  phenotypes
# Saving to tmp/phenotypes_interactions_202507291242.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/35138_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0  Unclassified-Unclassified             824212  phenotypes
# 1         PAX2+-Unclassified               2832  phenotypes
# 2                PAX2+-PAX2+                372  phenotypes
# 3    Stroma SMA-Unclassified             658154  phenotypes
# 4    Stroma VIM-Unclassified             554487  phenotypes
# Saving to tmp/phenotypes_interactions_202507291319.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/19E110099A4_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0  Unclassified-Unclassified            1928259  phenotypes
# 1         Tumor-Unclassified             100442  phenotypes
# 2        Immune-Unclassified              53630  phenotypes
# 3            M2-Unclassified              96250  phenotypes
# 4               Immune-Tumor              13002  phenotypes
# Saving to tmp/phenotypes_interactions_202507291354.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/1826315_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0  Unclassified-Unclassified            1089789  phenotypes
# 1         Tumor-Unclassified             180250  phenotypes
# 2        Immune-Unclassified              96442  phenotypes
# 3        T cell-Unclassified              60004  phenotypes
# 4               Immune-Tumor             125240  phenotypes
# Saving to tmp/phenotypes_interactions_202507291457.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/B19-10215_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0  Unclassified-Unclassified              68024  phenotypes
# 1         Tumor-Unclassified              59015  phenotypes
# 2   T cytotoxic-Unclassified                204  phenotypes
# 3          T cytotoxic-Tumor                414  phenotypes
# 4                Tumor-Tumor             141799  phenotypes
# Saving to tmp/phenotypes_interactions_202507291459.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/21S188_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0    Stroma VIM-Unclassified             446919  phenotypes
# 1         Tumor-Unclassified             256238  phenotypes
# 2           Stroma VIM-Tumor             166245  phenotypes
# 3  Unclassified-Unclassified            1090898  phenotypes
# 4    Stroma SMA-Unclassified              81649  phenotypes
# Saving to tmp/phenotypes_interactions_202507291522.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/21-37601_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0  Unclassified-Unclassified             247876  phenotypes
# 1         Tumor-Unclassified             155299  phenotypes
# 2    Stroma SMA-Unclassified             181247  phenotypes
# 3    Stroma VIM-Unclassified             212604  phenotypes
# 4           Stroma SMA-Tumor              46457  phenotypes
# Saving to tmp/phenotypes_interactions_202507291549.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/1923575_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0  Unclassified-Unclassified             542763  phenotypes
# 1            M2-Unclassified             118516  phenotypes
# 2              M2-Stroma SMA             268970  phenotypes
# 3    Stroma SMA-Unclassified             442670  phenotypes
# 4    Stroma VIM-Unclassified             267814  phenotypes
# Saving to tmp/phenotypes_interactions_202507291618.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/23S22_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0        Immune-Unclassified              23770  phenotypes
# 1  Unclassified-Unclassified             245588  phenotypes
# 2         Tumor-Unclassified              75896  phenotypes
# 3               Immune-Tumor               8278  phenotypes
# 4                Tumor-Tumor             239904  phenotypes
# Saving to tmp/phenotypes_interactions_202507291623.csv
# Adding to list...
# Loading /hpcnfs/techunits/imaging/work/ATTEND/analysis_runs/1818600_analysis/output/phenotypes_20250723.csv
# Counting interactions...
#                  interaction  interaction_count  patient_id
# 0                Tumor-Tumor            1575273  phenotypes
# 1  Unclassified-Unclassified             673350  phenotypes
# 2         PAX2+-Unclassified               3898  phenotypes
# 3         Tumor-Unclassified             191118  phenotypes
# 4                PAX2+-Tumor               1534  phenotypes
# Saving to tmp/phenotypes_interactions_202507291700.csv
# Adding to list...

# %%
interactions_df.head()
# Out:
#                  interaction  interaction_count  patient_id
# 0      Stroma SMA-Stroma SMA             544506  phenotypes
# 1    Stroma SMA-Unclassified             431332  phenotypes
# 2  Unclassified-Unclassified             776817  phenotypes
# 3                Tumor-Tumor             461062  phenotypes
# 4         Tumor-Unclassified              51786  phenotypes

# %%
# interactions_df.to_csv('data/phenotypes_interactions_20250730.csv', index=False)
